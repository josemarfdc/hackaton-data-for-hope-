# %% [markdown]
# # API queries

# %%
import urllib3

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:85% } </style>"))
# Out:
# <style>.container {width:85% } </style>

# %% [markdown]
# ## Sample urlib request
#
# (https://api.census.gov/data/2015/acs1/profile?get=DP05_0001E,DP05_0002E,DP05_0003E,DP05_0001M,DP05_0002M,DP05_0003M&for=congressional+district:00&in=state:56)

# %%
http = urllib3.PoolManager()
r = http.request('GET','https://api.census.gov/data/2015/acs1/profile?get=DP05_0001E,DP05_0002E,DP05_0003E,DP05_0001M,DP05_0002M,DP05_0003M&for=congressional+district:00&in=state:56')
# Out:
# /Users/FitzRoi/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# ##Parsing a list of County Codes (FIP) FROM https://www.census.gov/geo/reference/codes/cou.html

# %%
path_to_url_codes="../data/urls_to_county_codes/county_codes.txt"
fil = open(path_to_url_codes,"r")

# %%
lines=fil.readlines()

# %%
#Create a list of objects representing a county, their state and county_code

# %%
cty_census_code_list =[]
for url_str in lines:
    r = http.request('GET', url_str.strip())
    for line in r.data.split("\n"):
        county_list = line.split(",")
        cty_census_code_list.append({"state":county_list[0], "state_code":county_list[1],"county_code": county_list[2], "county_name": county_list[3]})
    
print cty_census_code_list
# Out:
# /Users/FitzRoi/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/FitzRoi/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/FitzRoi/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...

# %%
#link example 
#Example for FL (12), Bay County (005) , Housing Estimates (HUEST)
#https://api.census.gov/data/2016/pep/housing?get=DATE,GEONAME,HUEST&for=county:005&in=state:12&key=9a801321e90fa88baa4eff4638439da3be53766f
#other datasets
#https://www.census.gov/data/developers/data-sets.html
